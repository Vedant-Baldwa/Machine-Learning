# %%
import numpy as np
import pandas as pd


from sklearn.model_selection import train_test_split, GridSearchCV, StratifiedKFold, RandomizedSearchCV
from sklearn.linear_model import LinearRegression , Ridge , Lasso, LogisticRegression
from sklearn.preprocessing import StandardScaler, RobustScaler, QuantileTransformer, OneHotEncoder, FunctionTransformer, PolynomialFeatures, MaxAbsScaler, MinMaxScaler
from sklearn.tree import DecisionTreeRegressor, DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import mean_squared_error, r2_score,accuracy_score
from sklearn.pipeline import Pipeline
from sklearn.datasets import load_iris
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # **Why Optuna is usually better than Grid / Random search**
#
# * *Smarter sampling (Bayesian/TPE) — Optuna’s default TPESampler models which regions of the search space work well and focuses future trials there. Grid/Random are blind.*
#
# * *Fewer trials → less compute — because it learns from past trials, Optuna often finds good hyperparams with far fewer evaluations.*
#
# * *Early stopping / pruning — Optuna can stop unpromising trials early (via pruners), saving huge time for expensive trainings (e.g., deep nets or large XGBoost runs).*
#
# * *Flexible search spaces — handles continuous ranges, log scales, categorical choices, conditional hyperparameters (e.g., only suggest subsample if booster == 'gbtree').*
#
# * *Good reproducibility & logging — persistent storage (RDB), visualization tools (plot_optimization_history, plot_param_importances) and trial history make analysis easy.*
#
# * *Parallel & distributed-friendly — can run trials in parallel with a shared study DB (and integrates with Ray Tune, Dask, etc.).*
#
# * *Multi-objective — supports optimizing multiple objectives (e.g., accuracy and inference time).*
# ---
# # **When to use each method**
# ## **Grid Search**
# Use when:
#
# * *The search space is very small and you want exhaustive coverage (e.g., 2–3 hyperparams with a few values each).*
#
# *  *You need deterministic, exhaustive evaluation for reproducibility or debugging.*
#
# Don't use when:
# * You have many hyperparams or large ranges — grid explodes combinatorially.*
#
# ## **Randomized Search**
# Use when:
#
# * *You have many hyperparameters or large ranges and want a cheap baseline.*
#
# * *Evaluation is cheap and you can try many random combos.*
#
# * *You want a simple, robust baseline before applying smarter methods.*
#
# Don't use when:
# * *Each trial is expensive it wastes budget on poor regions because it doesn't learn.*
#
# ## **Optuna (Bayesian/TPE + pruning)**
# Use when:
#
# * *Trials are expensive (training large models, long CV). Optuna will find good settings faster.*
#
# * *You have continuous hyperparams, conditional parameters, or need pruning.*
#
# * *You want visualizations, persistent results, and easy integration.*
#
#
# Don’t use when:
#
# * *Search dimension is extremely high (>>20–30) and individual parameters are independent — random search may be competitive.*
#
# * *You want a tiny, guaranteed exhaustive search (then Grid is fine).*
# ---
# ## **Other hyperparameter optimization tools / frameworks (short list & when to pick them)**
#
# | **Tool**          | **Algo(s)**                        | **Best for**                                                   |
# | ------------- | ------------------------------ | ---------------------------------------------------------- |
# | Optuna        | TPE + pruners, multi-objective | Expensive trials, conditional spaces, parallel runs        |
# | Hyperopt      | TPE                            | Lightweight TPE usage                                      |
# | skopt         | GP                             | Low-dim continuous problems                                |
# | Ax/BoTorch    | GP, Botorch                    | Research/complex Bayesian optimization                     |
# | SMAC3         | RF surrogate                   | Categorical/conditional heavy spaces                       |
# | BOHB          | BO + Hyperband                 | Multi-fidelity, many cheap proxies                         |
# | Ray Tune      | Orchestration                  | Distributed large-scale tuning (works with many searchers) |
# | Grid / Random | Exhaustive/Random              | Simple baselines or tiny spaces                            |

# %% [markdown]
# #GridSearchCV

# %%
X, y = load_iris(return_X_y=True)
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
model = RandomForestClassifier()
model.get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': 'sqrt',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'monotonic_cst': None,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False}

# %%
# Hyperparameter grid
param_grid = {
    'n_estimators': [10,50,100,500],
    'max_depth': [2, 4, 8, 16, 32, 64, None],
    'min_samples_split':[2,10, 30, 50, 100, 200, 300, 700]
}

# GridSearchCV object
grid_search = GridSearchCV(estimator=model, param_grid=param_grid, cv=5, scoring='accuracy')

# Fit
grid_search.fit(X_train, y_train)

# Best parameters
print("Best parameters:", grid_search.best_params_)
# Out:
# Best parameters: {'max_depth': None, 'min_samples_split': 10, 'n_estimators': 50}
# Best CV accuracy: 0.9636363636363636
# Test accuracy: 1.0

# %%
# Best score
print("Best CV accuracy:", grid_search.best_score_)
# Evaluate on test set
print("Test accuracy:", grid_search.score(X_test, y_test))
print("Train accuracy:", grid_search.score(X_train,y_train))
# Out:
# Train accuracy: 0.9553571428571429

# %% [markdown]
# # RandomizedSearchCv

# %%
X, y = load_iris(return_X_y=True)
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
pipe=Pipeline([
    ('scaler',StandardScaler()),
    ('model',XGBClassifier(
        objective='multi:softprob',num_class=7,eval_metric='mlogloss',use_label_encoder=False,verbosity=0
        ))
])

#pipe.get_params()

# %%
import scipy.stats as stats
pram_grid={
    'model__n_estimators':[50,100,200],
    'model__max_depth':stats.randint(4,10),
    'model__learning_rate':[0.01,0.1,0.3],
    'model__reg_lambda':[0.01,0.1,1,10,100],
    'model__reg_alpha':[0.01,0.1,1,10,100],
    'scaler':[StandardScaler(),RobustScaler(),MaxAbsScaler(),MinMaxScaler()]
}

grid=RandomizedSearchCV(pipe,pram_grid,cv=5,n_jobs=-1,verbose=1,scoring='accuracy')
grid.fit(X_train,y_train)


best_params=grid.best_params_
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits

# %%
pipe.set_params(**best_params)

pipe.fit(X_train,y_train,model__eval_set=[(X_test,y_test)])
# Out:
# [0]	validation_0-mlogloss:1.10090
# [1]	validation_0-mlogloss:1.10340
# [2]	validation_0-mlogloss:1.10610
# [3]	validation_0-mlogloss:1.10898
# [4]	validation_0-mlogloss:1.11205
# [5]	validation_0-mlogloss:1.11529
# [6]	validation_0-mlogloss:1.11869
# [7]	validation_0-mlogloss:1.12226
# [8]	validation_0-mlogloss:1.12597
# [9]	validation_0-mlogloss:1.12983
# [10]	validation_0-mlogloss:1.13382
# [11]	validation_0-mlogloss:1.13794
# [12]	validation_0-mlogloss:1.14219
# [13]	validation_0-mlogloss:1.14655
# [14]	validation_0-mlogloss:1.15102
# [15]	validation_0-mlogloss:1.15560
# [16]	validation_0-mlogloss:1.16028
# [17]	validation_0-mlogloss:1.16505
# [18]	validation_0-mlogloss:1.16990
# [19]	validation_0-mlogloss:1.17484
# [20]	validation_0-mlogloss:1.17985
# [21]	validation_0-mlogloss:1.18494
# [22]	validation_0-mlogloss:1.19009
# [23]	validation_0-mlogloss:1.19531
# [24]	validation_0-mlogloss:1.20058
# [25]	validation_0-mlogloss:1.20591
# [26]	validation_0-mlogloss:1.21129
# [27]	validation_0-mlogloss:1.21671
# [28]	validation_0-mlogloss:1.22218
# [29]	validation_0-mlogloss:1.22769
# [30]	validation_0-mlogloss:1.23320
# [31]	validation_0-mlogloss:1.23651
# [32]	validation_0-mlogloss:1.23988
# [33]	validation_0-mlogloss:1.24326
# [34]	validation_0-mlogloss:1.24670
# [35]	validation_0-mlogloss:1.25232
# [36]	validation_0-mlogloss:1.25580
# [37]	validation_0-mlogloss:1.25930
# [38]	validation_0-mlogloss:1.26285
# [39]	validation_0-mlogloss:1.26643
# [40]	validation_0-mlogloss:1.27205
# [41]	validation_0-mlogloss:1.27566
# [42]	validation_0-mlogloss:1.27926
# [43]	validation_0-mlogloss:1.28292
# [44]	validation_0-mlogloss:1.28852
# [45]	validation_0-mlogloss:1.29220
# [46]	validation_0-mlogloss:1.29585
# [47]	validation_0-mlogloss:1.29955
# [48]	validation_0-mlogloss:1.30517
# [49]	validation_0-mlogloss:1.30884
# [50]	validation_0-mlogloss:1.31256
# [51]	validation_0-mlogloss:1.31624
# [52]	validation_0-mlogloss:1.31996
# [53]	validation_0-mlogloss:1.32552
# [54]	validation_0-mlogloss:1.32921
# [55]	validation_0-mlogloss:1.33294
# [56]	validation_0-mlogloss:1.33662
# [57]	validation_0-mlogloss:1.34211
# [58]	validation_0-mlogloss:1.34579
# [59]	validation_0-mlogloss:1.34951
# [60]	validation_0-mlogloss:1.35323
# [61]	validation_0-mlogloss:1.35859
# [62]	validation_0-mlogloss:1.36230
# [63]	validation_0-mlogloss:1.36595
# [64]	validation_0-mlogloss:1.36964
# [65]	validation_0-mlogloss:1.37497
# [66]	validation_0-mlogloss:1.37859
# [67]	validation_0-mlogloss:1.38226
# [68]	validation_0-mlogloss:1.38535
# [69]	validation_0-mlogloss:1.39006
# [70]	validation_0-mlogloss:1.39370
# [71]	validation_0-mlogloss:1.39677
# [72]	validation_0-mlogloss:1.39983
# [73]	validation_0-mlogloss:1.40344
# [74]	validation_0-mlogloss:1.40649
# [75]	validation_0-mlogloss:1.40953
# [76]	validation_0-mlogloss:1.41256
# [77]	validation_0-mlogloss:1.41559
# [78]	validation_0-mlogloss:1.41860
# [79]	validation_0-mlogloss:1.42314
# [80]	validation_0-mlogloss:1.42665
# [81]	validation_0-mlogloss:1.43015
# [82]	validation_0-mlogloss:1.43313
# [83]	validation_0-mlogloss:1.43611
# [84]	validation_0-mlogloss:1.44056
# [85]	validation_0-mlogloss:1.44400
# [86]	validation_0-mlogloss:1.44695
# [87]	validation_0-mlogloss:1.45134
# [88]	validation_0-mlogloss:1.45474
# [89]	validation_0-mlogloss:1.45910
# [90]	validation_0-mlogloss:1.46247
# [91]	validation_0-mlogloss:1.46679
# [92]	validation_0-mlogloss:1.47014
# [93]	validation_0-mlogloss:1.47487
# [94]	validation_0-mlogloss:1.47958
# [95]	validation_0-mlogloss:1.48288
# [96]	validation_0-mlogloss:1.48754
# [97]	validation_0-mlogloss:1.49081
# [98]	validation_0-mlogloss:1.49543
# [99]	validation_0-mlogloss:1.49867
# [100]	validation_0-mlogloss:1.50282
# [101]	validation_0-mlogloss:1.50737
# [102]	validation_0-mlogloss:1.51056
# [103]	validation_0-mlogloss:1.51466
# [104]	validation_0-mlogloss:1.51782
# [105]	validation_0-mlogloss:1.52188
# [106]	validation_0-mlogloss:1.52501
# [107]	validation_0-mlogloss:1.52771
# [108]	validation_0-mlogloss:1.53040
# [109]	validation_0-mlogloss:1.53307
# [110]	validation_0-mlogloss:1.53574
# [111]	validation_0-mlogloss:1.53969
# [112]	validation_0-mlogloss:1.54273
# [113]	validation_0-mlogloss:1.54537
# [114]	validation_0-mlogloss:1.54800
# [115]	validation_0-mlogloss:1.55061
# [116]	validation_0-mlogloss:1.55322
# [117]	validation_0-mlogloss:1.55581
# [118]	validation_0-mlogloss:1.55841
# [119]	validation_0-mlogloss:1.56099
# [120]	validation_0-mlogloss:1.56355
# [121]	validation_0-mlogloss:1.56610
# [122]	validation_0-mlogloss:1.56986
# [123]	validation_0-mlogloss:1.57240
# [124]	validation_0-mlogloss:1.57492
# [125]	validation_0-mlogloss:1.57743
# [126]	validation_0-mlogloss:1.57994
# [127]	validation_0-mlogloss:1.58243
# [128]	validation_0-mlogloss:1.58491
# [129]	validation_0-mlogloss:1.58880
# [130]	validation_0-mlogloss:1.59127
# [131]	validation_0-mlogloss:1.59372
# [132]	validation_0-mlogloss:1.59616
# [133]	validation_0-mlogloss:1.59858
# [134]	validation_0-mlogloss:1.60100
# [135]	validation_0-mlogloss:1.60453
# [136]	validation_0-mlogloss:1.60693
# [137]	validation_0-mlogloss:1.60932
# [138]	validation_0-mlogloss:1.61170
# [139]	validation_0-mlogloss:1.61406
# [140]	validation_0-mlogloss:1.61751
# [141]	validation_0-mlogloss:1.61985
# [142]	validation_0-mlogloss:1.62219
# [143]	validation_0-mlogloss:1.62452
# [144]	validation_0-mlogloss:1.62683
# [145]	validation_0-mlogloss:1.62914
# [146]	validation_0-mlogloss:1.63143
# [147]	validation_0-mlogloss:1.63477
# [148]	validation_0-mlogloss:1.63704
# [149]	validation_0-mlogloss:1.63930
# [150]	validation_0-mlogloss:1.64156
# [151]	validation_0-mlogloss:1.64381
# [152]	validation_0-mlogloss:1.64707
# [153]	validation_0-mlogloss:1.64929
# [154]	validation_0-mlogloss:1.65151
# [155]	validation_0-mlogloss:1.65372
# [156]	validation_0-mlogloss:1.65592
# [157]	validation_0-mlogloss:1.65811
# [158]	validation_0-mlogloss:1.66029
# [159]	validation_0-mlogloss:1.66345
# [160]	validation_0-mlogloss:1.66560
# [161]	validation_0-mlogloss:1.66775
# [162]	validation_0-mlogloss:1.66990
# [163]	validation_0-mlogloss:1.67204
# [164]	validation_0-mlogloss:1.67415
# [165]	validation_0-mlogloss:1.67626
# [166]	validation_0-mlogloss:1.67837
# [167]	validation_0-mlogloss:1.68141
# [168]	validation_0-mlogloss:1.68349
# [169]	validation_0-mlogloss:1.68557
# [170]	validation_0-mlogloss:1.68764
# [171]	validation_0-mlogloss:1.68971
# [172]	validation_0-mlogloss:1.69176
# [173]	validation_0-mlogloss:1.69472
# [174]	validation_0-mlogloss:1.69689
# [175]	validation_0-mlogloss:1.69892
# [176]	validation_0-mlogloss:1.70094
# [177]	validation_0-mlogloss:1.70295
# [178]	validation_0-mlogloss:1.70495
# [179]	validation_0-mlogloss:1.70797
# [180]	validation_0-mlogloss:1.70996
# [181]	validation_0-mlogloss:1.71207
# [182]	validation_0-mlogloss:1.71491
# [183]	validation_0-mlogloss:1.71699
# [184]	validation_0-mlogloss:1.71894
# [185]	validation_0-mlogloss:1.72088
# [186]	validation_0-mlogloss:1.72282
# [187]	validation_0-mlogloss:1.72474
# [188]	validation_0-mlogloss:1.72750
# [189]	validation_0-mlogloss:1.72954
# [190]	validation_0-mlogloss:1.73144
# [191]	validation_0-mlogloss:1.73417
# [192]	validation_0-mlogloss:1.73615
# [193]	validation_0-mlogloss:1.73803
# [194]	validation_0-mlogloss:1.73990
# [195]	validation_0-mlogloss:1.74173
# [196]	validation_0-mlogloss:1.74437
# [197]	validation_0-mlogloss:1.74631
# [198]	validation_0-mlogloss:1.74892
# [199]	validation_0-mlogloss:1.75070
# Pipeline(steps=[('scaler', MaxAbsScaler()),
#                 ('model',
#                  XGBClassifier(base_score=None, booster=None, callbacks=None,
#                                colsample_bylevel=None, colsample_bynode=None,
#                                colsample_bytree=None, device=None,
#                                early_stopping_rounds=None,
#                                enable_categorical=False, eval_metric='mlogloss',
#                                feature_types=None, feature_weights=None,
#                                gamma=None, grow_policy=None,
#                                importance_type=None,
#                                interaction_constraints=None, learning_rate=0.1,
#                                max_bin=None, max_cat_threshold=None,
#                                max_cat_to_onehot=None, max_delta_step=None,
#                                max_depth=5, max_leaves=None,
#                                min_child_weight=None, missing=nan,
#                                monotone_constraints=None, multi_strategy=None,
#                                n_estimators=200, n_jobs=None, num_class=7, ...))])

# %% [markdown]
# # Optuna

# %%
# !pip install optuna
# Out:
# Collecting optuna
#   Downloading optuna-4.5.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (1.16.5)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (25.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.43)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from optuna) (6.0.3)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (1.3.10)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (4.15.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.2.4)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.12/dist-packages (from Mako->alembic>=1.5.0->optuna) (3.0.3)
# Downloading optuna-4.5.0-py3-none-any.whl (400 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.9/400.9 kB 8.1 MB/s eta 0:00:00
# Downloading colorlog-6.9.0-py3-none-any.whl (11 kB)
# Installing collected packages: colorlog, optuna
# Successfully installed colorlog-6.9.0 optuna-4.5.0

# %%
import optuna

# %%
X, y = load_iris(return_X_y=True)
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
def objective(trial):
    n_estimators = trial.suggest_int('n_estimators', 10, 200)                       #write the range of the parameter
    max_depth = trial.suggest_int('max_depth', 2, 32)
    clf = RandomForestClassifier(n_estimators=n_estimators, max_depth=max_depth)
    clf.fit(X_train, y_train)
    y_pred = clf.predict(X_test)
    return accuracy_score(y_test, y_pred)

study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=50)

study.best_params
# Out:
# [I 2025-10-08 17:39:44,988] A new study created in memory with name: no-name-629af135-c8fd-407e-a843-3abd4d3350cf
# [I 2025-10-08 17:39:45,147] Trial 0 finished with value: 1.0 and parameters: {'n_estimators': 58, 'max_depth': 25}. Best is trial 0 with value: 1.0.
# [I 2025-10-08 17:39:45,247] Trial 1 finished with value: 1.0 and parameters: {'n_estimators': 35, 'max_depth': 24}. Best is trial 0 with value: 1.0.
# [I 2025-10-08 17:39:45,357] Trial 2 finished with value: 1.0 and parameters: {'n_estimators': 35, 'max_depth': 27}. Best is trial 0 with value: 1.0.
# [I 2025-10-08 17:39:45,660] Trial 3 finished with value: 1.0 and parameters: {'n_estimators': 89, 'max_depth': 22}. Best is trial 0 with value: 1.0.
# [I 2025-10-08 17:39:46,267] Trial 4 finished with value: 1.0 and parameters: {'n_estimators': 200, 'max_depth': 22}. Best is trial 0 with value: 1.0.
# [I 2025-10-08 17:39:46,935] Trial 5 finished with value: 1.0 and parameters: {'n_estimators': 170, 'max_depth': 30}. Best is trial 0 with value: 1.0.
# [I 2025-10-08 17:39:47,175] Trial 6 finished with value: 1.0 and parameters: {'n_estimators': 157, 'max_depth': 4}. Best is trial 0 with value: 1.0.
# [I 2025-10-08 17:39:47,302] Trial 7 finished with value: 1.0 and parameters: {'n_estimators': 75, 'max_depth': 30}. Best is trial 0 with value: 1.0.
# [I 2025-10-08 17:39:48,009] Trial 8 finished with value: 1.0 and parameters: {'n_estimators': 178, 'max_depth': 21}. Best is trial 0 with value: 1.0.
# [I 2025-10-08 17:39:48,237] Trial 9 finished with value: 1.0 and parameters: {'n_estimators': 146, 'max_depth': 11}. Best is trial 0 with value: 1.0.
# [I 2025-10-08 17:39:48,265] Trial 10 finished with value: 1.0 and parameters: {'n_estimators': 10, 'max_depth': 14}. Best is trial 0 with value: 1.0.
# [I 2025-10-08 17:39:48,361] Trial 11 finished with value: 1.0 and parameters: {'n_estimators': 53, 'max_depth': 25}. Best is trial 0 with value: 1.0.
# [I 2025-10-08 17:39:48,941] Trial 12 finished with value: 1.0 and parameters: {'n_estimators': 112, 'max_depth': 18}. Best is trial 0 with value: 1.0.
# [I 2025-10-08 17:39:49,022] Trial 13 finished with value: 1.0 and parameters: {'n_estimators': 47, 'max_depth': 26}. Best is trial 0 with value: 1.0.
# [I 2025-10-08 17:39:49,047] Trial 14 finished with value: 1.0 and parameters: {'n_estimators': 10, 'max_depth': 32}. Best is trial 0 with value: 1.0.
# [I 2025-10-08 17:39:49,225] Trial 15 finished with value: 1.0 and parameters: {'n_estimators': 112, 'max_depth': 17}. Best is trial 0 with value: 1.0.
# [I 2025-10-08 17:39:49,350] Trial 16 finished with value: 1.0 and parameters: {'n_estimators': 72, 'max_depth': 9}. Best is trial 0 with value: 1.0.
# [I 2025-10-08 17:39:49,410] Trial 17 finished with value: 1.0 and parameters: {'n_estimators': 32, 'max_depth': 20}. Best is trial 0 with value: 1.0.
# [I 2025-10-08 17:39:49,515] Trial 18 finished with value: 1.0 and parameters: {'n_estimators': 62, 'max_depth': 25}. Best is trial 0 with value: 1.0.
# [I 2025-10-08 17:39:49,674] Trial 19 finished with value: 1.0 and parameters: {'n_estimators': 95, 'max_depth': 14}. Best is trial 0 with value: 1.0.
# [I 2025-10-08 17:39:49,878] Trial 20 finished with value: 1.0 and parameters: {'n_estimators': 129, 'max_depth': 2}. Best is trial 0 with value: 1.0.
# [I 2025-10-08 17:39:49,943] Trial 21 finished with value: 1.0 and parameters: {'n_estimators': 25, 'max_depth': 28}. Best is trial 0 with value: 1.0.
# [I 2025-10-08 17:39:50,008] Trial 22 finished with value: 1.0 and parameters: {'n_estimators': 35, 'max_depth': 27}. Best is trial 0 with value: 1.0.
# [I 2025-10-08 17:39:50,087] Trial 23 finished with value: 1.0 and parameters: {'n_estimators': 45, 'max_depth': 24}. Best is trial 0 with value: 1.0.
# [I 2025-10-08 17:39:50,206] Trial 24 finished with value: 1.0 and parameters: {'n_estimators': 71, 'max_depth': 29}. Best is trial 0 with value: 1.0.
# [I 2025-10-08 17:39:50,264] Trial 25 finished with value: 1.0 and parameters: {'n_estimators': 25, 'max_depth': 23}. Best is trial 0 with value: 1.0.
# [I 2025-10-08 17:39:50,365] Trial 26 finished with value: 1.0 and parameters: {'n_estimators': 57, 'max_depth': 19}. Best is trial 0 with value: 1.0.
# [I 2025-10-08 17:39:50,503] Trial 27 finished with value: 1.0 and parameters: {'n_estimators': 84, 'max_depth': 32}. Best is trial 0 with value: 1.0.
# [I 2025-10-08 17:39:50,575] Trial 28 finished with value: 1.0 and parameters: {'n_estimators': 40, 'max_depth': 16}. Best is trial 0 with value: 1.0.
# [I 2025-10-08 17:39:50,729] Trial 29 finished with value: 1.0 and parameters: {'n_estimators': 95, 'max_depth': 23}. Best is trial 0 with value: 1.0.
# [I 2025-10-08 17:39:50,774] Trial 30 finished with value: 1.0 and parameters: {'n_estimators': 23, 'max_depth': 28}. Best is trial 0 with value: 1.0.
# [I 2025-10-08 17:39:50,886] Trial 31 finished with value: 1.0 and parameters: {'n_estimators': 62, 'max_depth': 22}. Best is trial 0 with value: 1.0.
# [I 2025-10-08 17:39:51,037] Trial 32 finished with value: 1.0 and parameters: {'n_estimators': 82, 'max_depth': 21}. Best is trial 0 with value: 1.0.
# [I 2025-10-08 17:39:51,194] Trial 33 finished with value: 1.0 and parameters: {'n_estimators': 94, 'max_depth': 26}. Best is trial 0 with value: 1.0.
# [I 2025-10-08 17:39:51,285] Trial 34 finished with value: 1.0 and parameters: {'n_estimators': 52, 'max_depth': 24}. Best is trial 0 with value: 1.0.
# [I 2025-10-08 17:39:51,403] Trial 35 finished with value: 1.0 and parameters: {'n_estimators': 67, 'max_depth': 30}. Best is trial 0 with value: 1.0.
# [I 2025-10-08 17:39:51,539] Trial 36 finished with value: 1.0 and parameters: {'n_estimators': 81, 'max_depth': 21}. Best is trial 0 with value: 1.0.
# [I 2025-10-08 17:39:51,605] Trial 37 finished with value: 1.0 and parameters: {'n_estimators': 36, 'max_depth': 26}. Best is trial 0 with value: 1.0.
# [I 2025-10-08 17:39:51,903] Trial 38 finished with value: 1.0 and parameters: {'n_estimators': 188, 'max_depth': 23}. Best is trial 0 with value: 1.0.
# [I 2025-10-08 17:39:52,134] Trial 39 finished with value: 1.0 and parameters: {'n_estimators': 134, 'max_depth': 30}. Best is trial 0 with value: 1.0.
# [I 2025-10-08 17:39:52,175] Trial 40 finished with value: 1.0 and parameters: {'n_estimators': 18, 'max_depth': 28}. Best is trial 0 with value: 1.0.
# [I 2025-10-08 17:39:52,422] Trial 41 finished with value: 1.0 and parameters: {'n_estimators': 148, 'max_depth': 19}. Best is trial 0 with value: 1.0.
# [I 2025-10-08 17:39:52,676] Trial 42 finished with value: 1.0 and parameters: {'n_estimators': 157, 'max_depth': 25}. Best is trial 0 with value: 1.0.
# [I 2025-10-08 17:39:52,938] Trial 43 finished with value: 1.0 and parameters: {'n_estimators': 166, 'max_depth': 22}. Best is trial 0 with value: 1.0.
# [I 2025-10-08 17:39:53,150] Trial 44 finished with value: 1.0 and parameters: {'n_estimators': 119, 'max_depth': 16}. Best is trial 0 with value: 1.0.
# [I 2025-10-08 17:39:53,320] Trial 45 finished with value: 1.0 and parameters: {'n_estimators': 101, 'max_depth': 20}. Best is trial 0 with value: 1.0.
# [I 2025-10-08 17:39:53,401] Trial 46 finished with value: 1.0 and parameters: {'n_estimators': 44, 'max_depth': 8}. Best is trial 0 with value: 1.0.
# [I 2025-10-08 17:39:53,709] Trial 47 finished with value: 1.0 and parameters: {'n_estimators': 194, 'max_depth': 25}. Best is trial 0 with value: 1.0.
# [I 2025-10-08 17:39:53,740] Trial 48 finished with value: 1.0 and parameters: {'n_estimators': 11, 'max_depth': 31}. Best is trial 0 with value: 1.0.
# [I 2025-10-08 17:39:53,828] Trial 49 finished with value: 1.0 and parameters: {'n_estimators': 51, 'max_depth': 27}. Best is trial 0 with value: 1.0.
# {'n_estimators': 58, 'max_depth': 25}

# %%
import optuna
from optuna.samplers import TPESampler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import StandardScaler, RobustScaler, MaxAbsScaler, MinMaxScaler
from xgboost import XGBClassifier
import numpy as np

def objective(trial):

    n_estimators = trial.suggest_int('n_estimators', 50, 200)
    max_depth = trial.suggest_int('max_depth', 4, 10)
    learning_rate = trial.suggest_float('learning_rate', 0.01, 0.3, log=True)
    reg_lambda = trial.suggest_float('reg_lambda', 0.01, 100, log=True)
    reg_alpha = trial.suggest_float('reg_alpha', 0.01, 100, log=True)
    scaler_name = trial.suggest_categorical('scaler',
                    ['standard', 'robust', 'maxabs', 'minmax'])


    scalers = {
        'standard': StandardScaler(),
        'robust': RobustScaler(),
        'maxabs': MaxAbsScaler(),
        'minmax': MinMaxScaler()
    }
    scaler = scalers[scaler_name]


    pipe = Pipeline([
        ('scaler', scaler),
        ('model', XGBClassifier(
            objective='multi:softprob',
            num_class=7,
            eval_metric='mlogloss',
            use_label_encoder=False,
            verbosity=0,
            n_estimators=n_estimators,
            max_depth=max_depth,
            learning_rate=learning_rate,
            reg_lambda=reg_lambda,
            reg_alpha=reg_alpha
        ))
    ])

    scores = cross_val_score(pipe, X_train, y_train, cv=5, scoring='accuracy', n_jobs=-1)
    return np.mean(scores)

# %%
study = optuna.create_study(
    direction='maximize',
    sampler=TPESampler(seed=42)
)

study.optimize(objective, n_trials=50, show_progress_bar=True)
# Out:
# [I 2025-10-08 17:48:33,814] A new study created in memory with name: no-name-99aadb69-119c-437b-a719-1d7e15b6076f
#   0%|          | 0/50 [00:00<?, ?it/s]
# [I 2025-10-08 17:48:36,091] Trial 0 finished with value: 0.9371541501976285 and parameters: {'n_estimators': 106, 'max_depth': 10, 'learning_rate': 0.1205712628744377, 'reg_lambda': 2.481040974867813, 'reg_alpha': 0.04207988669606638, 'scaler': 'maxabs'}. Best is trial 0 with value: 0.9371541501976285.
# [I 2025-10-08 17:48:36,338] Trial 1 finished with value: 0.9371541501976285 and parameters: {'n_estimators': 156, 'max_depth': 4, 'learning_rate': 0.2708160864249968, 'reg_lambda': 21.368329072358772, 'reg_alpha': 0.07068974950624607, 'scaler': 'minmax'}. Best is trial 0 with value: 0.9371541501976285.
# [I 2025-10-08 17:48:36,515] Trial 2 finished with value: 0.9371541501976285 and parameters: {'n_estimators': 115, 'max_depth': 6, 'learning_rate': 0.08012737503998542, 'reg_lambda': 0.03613894271216528, 'reg_alpha': 0.14742753159914673, 'scaler': 'maxabs'}. Best is trial 0 with value: 0.9371541501976285.
# [I 2025-10-08 17:48:36,721] Trial 3 finished with value: 0.9454545454545455 and parameters: {'n_estimators': 127, 'max_depth': 8, 'learning_rate': 0.011711509955524094, 'reg_lambda': 2.69264691008618, 'reg_alpha': 0.04809461967501574, 'scaler': 'maxabs'}. Best is trial 3 with value: 0.9454545454545455.
# [I 2025-10-08 17:48:36,880] Trial 4 finished with value: 0.9371541501976285 and parameters: {'n_estimators': 95, 'max_depth': 4, 'learning_rate': 0.1024932221692416, 'reg_lambda': 0.5762487216478605, 'reg_alpha': 0.030771802712506867, 'scaler': 'maxabs'}. Best is trial 3 with value: 0.9454545454545455.
# [I 2025-10-08 17:48:37,102] Trial 5 finished with value: 0.9371541501976285 and parameters: {'n_estimators': 150, 'max_depth': 6, 'learning_rate': 0.05864129169696527, 'reg_lambda': 1.5375920235481764, 'reg_alpha': 0.05488047000766046, 'scaler': 'standard'}. Best is trial 3 with value: 0.9454545454545455.
# [I 2025-10-08 17:48:37,352] Trial 6 finished with value: 0.9367588932806324 and parameters: {'n_estimators': 140, 'max_depth': 10, 'learning_rate': 0.01351182947645082, 'reg_lambda': 0.06080390190296603, 'reg_alpha': 0.015167330688076212, 'scaler': 'minmax'}. Best is trial 3 with value: 0.9454545454545455.
# [I 2025-10-08 17:48:37,492] Trial 7 finished with value: 0.9189723320158103 and parameters: {'n_estimators': 103, 'max_depth': 5, 'learning_rate': 0.06333268775321842, 'reg_lambda': 0.0366181922039243, 'reg_alpha': 16.172900811143155, 'scaler': 'robust'}. Best is trial 3 with value: 0.9454545454545455.
# [I 2025-10-08 17:48:37,588] Trial 8 finished with value: 0.9189723320158103 and parameters: {'n_estimators': 50, 'max_depth': 9, 'learning_rate': 0.11069143219393454, 'reg_lambda': 8.241925264876455, 'reg_alpha': 12.164139351417068, 'scaler': 'minmax'}. Best is trial 3 with value: 0.9454545454545455.
# [I 2025-10-08 17:48:37,809] Trial 9 finished with value: 0.9458498023715414 and parameters: {'n_estimators': 144, 'max_depth': 6, 'learning_rate': 0.012413189635294229, 'reg_lambda': 0.17535949529764422, 'reg_alpha': 0.19986340778528885, 'scaler': 'maxabs'}. Best is trial 9 with value: 0.9458498023715414.
# [I 2025-10-08 17:48:38,113] Trial 10 finished with value: 0.9371541501976285 and parameters: {'n_estimators':
 'scaler': 'maxabs'}. Best is trial 14 with value: 0.9545454545454547.
# [I 2025-10-08 17:48:46,948] Trial 43 finished with value: 0.9371541501976285 and parameters: {'n_estimators': 173, 'max_depth': 4, 'learning_rate': 0.026669038705913892, 'reg_lambda': 1.0762477885794057, 'reg_alpha': 1.6651562197382963, 'scaler': 'maxabs'}. Best is trial 14 with value: 0.9545454545454547.
# [I 2025-10-08 17:48:47,164] Trial 44 finished with value: 0.9545454545454547 and parameters: {'n_estimators': 159, 'max_depth': 6, 'learning_rate': 0.06222299712867951, 'reg_lambda': 0.04941321258745686, 'reg_alpha': 4.61654856663885, 'scaler': 'maxabs'}. Best is trial 14 with value: 0.9545454545454547.
# [I 2025-10-08 17:48:47,417] Trial 45 finished with value: 0.9371541501976285 and parameters: {'n_estimators': 150, 'max_depth': 5, 'learning_rate': 0.020670758303327208, 'reg_lambda': 0.024664394145101347, 'reg_alpha': 1.0467067969456152, 'scaler': 'robust'}. Best is trial 14 with value: 0.9545454545454547.
# [I 2025-10-08 17:48:47,611] Trial 46 finished with value: 0.3126482213438735 and parameters: {'n_estimators': 190, 'max_depth': 6, 'learning_rate': 0.03511989978131999, 'reg_lambda': 0.016617587608155352, 'reg_alpha': 21.21394067915816, 'scaler': 'maxabs'}. Best is trial 14 with value: 0.9545454545454547.
# [I 2025-10-08 17:48:47,882] Trial 47 finished with value: 0.9545454545454547 and parameters: {'n_estimators': 177, 'max_depth': 7, 'learning_rate': 0.025196670264418655, 'reg_lambda': 23.856029412303254, 'reg_alpha': 0.7886106048713325, 'scaler': 'standard'}. Best is trial 14 with value: 0.9545454545454547.
# [I 2025-10-08 17:48:48,099] Trial 48 finished with value: 0.9458498023715414 and parameters: {'n_estimators': 104, 'max_depth': 4, 'learning_rate': 0.016011412095714047, 'reg_lambda': 0.03317532001705218, 'reg_alpha': 0.3637763300214857, 'scaler': 'maxabs'}. Best is trial 14 with value: 0.9545454545454547.
# [I 2025-10-08 17:48:48,251] Trial 49 finished with value: 0.9189723320158103 and parameters: {'n_estimators': 93, 'max_depth': 5, 'learning_rate': 0.04605891903161382, 'reg_lambda': 0.07856290074250949, 'reg_alpha': 11.794319845969337, 'scaler': 'maxabs'}. Best is trial 14 with value: 0.9545454545454547.

# %%
optuna.visualization.plot_optimization_history(study)
optuna.visualization.plot_param_importances(study)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="e188ddde-370c-4f71-9e00-f71e2cebfda2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e188ddde-370c-4f71-9e00-f71e2cebfda2")) {                    Plotly.newPlot(                        "e188ddde-370c-4f71-9e00-f71e2cebfda2",                        [{"cliponaxis":false,"hovertemplate":["reg_lambda (FloatDistribution): 5.537938754947142e-08\u003cextra\u003e\u003c\u002fextra\u003e","max_depth (IntDistribution): 1.4415473574003162e-07\u003cextra\u003e\u003c\u002fextra\u003e","scaler (CategoricalDistribution): 3.495754184537885e-07\u003cextra\u003e\u003c\u002fextra\u003e","learning_rate (FloatDistribution): 3.8272894813603263e-07\u003cextra\u003e\u003c\u002fextra\u003e","n_estimators (IntDistribution): 0.015739239636946577\u003cextra\u003e\u003c\u002fextra\u003e","reg_alpha (FloatDistribution): 0.9842598285245636\u003cextra\u003e\u003c\u002fextra\u003e"],"name":"Objective Value","orientation":"h","text":["\u003c0.01","\u003c0.01","\u003c0.01","\u003c0.01","0.02","0.98"],"textposition":"outside","x":[5.537938754947142e-8,1.4415473574003162e-7,3.495754184537885e-7,3.8272894813603263e-7,0.015739239636946577,0.9842598285245636],"y":["reg_lambda","max_depth","scaler","learning_rate","n_estimators","reg_alpha"],"type":"bar"}],                        {"title":{"text":"Hyperparameter Importances"},"xaxis":{"title":{"text":"Hyperparameter Importance"}},"yaxis":{"title":{"text":"Hyperparameter"}},"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.55 ...

# %%
print("Best Accuracy:", study.best_value)
print("Best Params:", study.best_params)
# Out:
# Best Accuracy: 0.9545454545454547
# Best Params: {'n_estimators': 166, 'max_depth': 6, 'learning_rate': 0.026477567045245964, 'reg_lambda': 0.014264892990890433, 'reg_alpha': 4.018492967981209, 'scaler': 'maxabs'}

# %%
best_params = study.best_params
best_scaler = {
    'standard': StandardScaler(),
    'robust': RobustScaler(),
    'maxabs': MaxAbsScaler(),
    'minmax': MinMaxScaler()
}[best_params['scaler']]

best_model = Pipeline([
    ('scaler', best_scaler),
    ('model', XGBClassifier(
        objective='multi:softprob',
        num_class=7,
        eval_metric='mlogloss',
        use_label_encoder=False,
        verbosity=0,
        **{k: v for k, v in best_params.items() if k != 'scaler'}
    ))
])
#best_model.fit(X_train, y_train)
